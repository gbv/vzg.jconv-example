# %% [markdown]
# # Konvertierung einer Metadaten Datei in VZG JSON
#
# In diesem Notebook wird eine XML-Datei mit Metadaten zu einem [Artikel](https://dx.doi.org/10.1140/epjc/s10052-019-7027-6) in eine VZG JSON-Datei umgewandelt.
#
# Das Ausgangsformat liegt dabei im [JATS](https://jats.nlm.nih.gov/archiving/tag-library/1.1d1/) Format vor.
#
# Die neu erstellten Daten werden dann in das [VZG-JSON Schema](https://github.com/gbv/articleformat) überführt.

# %% [markdown]
# ## Einfaches Beispiel
#
# Die Ausgansdatei wird genutzt, um einmal beispielhaft zu zeigen, wie die Konvertierung im Prinzip verläuft.
#
# Dabei wird aus der Ausgansdatei ein Datensatz erzeugt, der den Minimalanforderungen des VZG JSON Schemas genügt.

# %%
from pathlib import Path
from pprint import pprint
from IPython.display import Markdown
from lxml import etree
from vzg.jconv.gapi import NAMESPACES
from vzg.jconv.langcode import ISO_639
from vzg.jconv.gapi import JSON_SCHEMA
import jsonschema
import json
import logging

logging.basicConfig(level=50)

xmldir = Path(".").absolute()
xmlpath = xmldir / "article.xml"
iso639 = ISO_639()

def simple_example():
    if not xmlpath.exists():
        print("Datei existiert nicht. {}".format(xmlpath.name))
        return None

    print("{} wird bearbeitet\n".format(xmlpath.name))
    
    article = {"abstracts": [{'text': ""}],
               "journal": {},
               "lang_code": "",
               "primary_id": {}, 
               "title": "Test", }
    
    # XML-Datei einlesen
    with open(xmlpath, 'rb') as fh:
        dom = etree.parse(fh)

    # Hilfsfunktionen
    def xpath(expression):
        return dom.xpath(expression, namespaces=NAMESPACES)
    
    def totext(node):
        return etree.tostring(node, encoding="utf-8", method="text").decode()
    
    # Titel des Artikels
    titlenode = xpath("//article-meta/title-group/article-title")[0]
    article['title'] = totext(titlenode)

    # Abstract
    attributes = xpath("//article-meta/abstract/@xml:lang")
    article["abstracts"][0]['lang_code'] = iso639.i1toi2[attributes[0]]

    sections = xpath("//article-meta/abstract")
    
    atext = []

    for secnode in sections:
        nodes = secnode.xpath("title")
        if len(nodes) > 0:
            atext.append(totext(nodes[0]))

        paras = [totext(para) for para in secnode.xpath("p")]
        atext += paras

    atext = [para for para in atext if isinstance(para, str)]
    article["abstracts"][0]['text'] = "\n\n".join(atext)
    
    # Primärer Identifier
    pdict = {"type": "SPRINGER", "id": ""}
    pdict['id'] = xpath("""//article-meta/article-id[@pub-id-type="publisher-id"]/text()""")[0]
    article["primary_id"] = pdict
    
    # Zeitschrift
    jdict = {"title": "", "year": ""}
    
    jdict["title"] = xpath("//journal-meta/journal-title-group/journal-title/text()")[0].strip()
    
    pubnode = xpath("""//article-meta/pub-date[@date-type="epub"]""")[0]
    jdict["year"] = pubnode.xpath("year/text()")[0]
    
    article["journal"] = jdict
    
    # Sprachcode
    attributes = xpath("//article-meta/title-group/article-title/@xml:lang")
    article['lang_code'] = [iso639.i1toi2[attributes[0]]]
    
    return article

# Konvertierung starten
article = simple_example()

# Test, ob die erzeugten Daten dem VZG Artikelformat entsprechen
jsonschema.validate(instance=article, schema=JSON_SCHEMA)

# Das erzeugte Python Dictionary anzeigen
pprint(article)

# Die konvertierten Daten als JSON Datei abspeichern
with open("article-simple.json", "w") as jfh:
    json.dump(article, jfh)

mdtext = """### {}

Zeitschrift: {} ({})
""".format(article['title'], article["journal"]["title"], article["journal"]["year"])

if len(article['abstracts']) > 0:
    abstract = article['abstracts'][0]['text']
    mdtext += """\n{}""".format(abstract)

# Die Daten aus der Konvertierung benutzen, um diese formatiert anzuzeigen 
Markdown(mdtext)
# Out:
# article.xml wird bearbeitet
#
# {'abstracts': [{'lang_code': 'eng',
#                 'text': 'Abstract\n'
#                         '\n'
#                         'This paper presents measurements of '
#                         'W±Z\\documentclass[12pt]{minimal}\n'
#                         '\t\t\t\t\\usepackage{amsmath}\n'
#                         '\t\t\t\t\\usepackage{wasysym}\n'
#                         '\t\t\t\t\\usepackage{amsfonts}\n'
#                         '\t\t\t\t\\usepackage{amssymb}\n'
#                         '\t\t\t\t\\usepackage{amsbsy}\n'
#                         '\t\t\t\t\\usepackage{mathrsfs}\n'
#                         '\t\t\t\t\\usepackage{upgreek}\n'
#                         '\t\t\t\t\\setlength{\\oddsidemargin}{-69pt}\n'
#                         '\t\t\t\t\\begin{document}$$W^{\\pm '
#                         '}Z$$\\end{document} production cross sections in pp '
#                         'collisions at a centre-of-mass energy of 13\xa0'
#                         'TeV\\documentclass[12pt]{minimal}\n'
#                         '\t\t\t\t\\usepackage{amsmath}\n'
#                         '\t\t\t\t\\usepackage{wasysym}\n'
#                         '\t\t\t\t\\usepackage{amsfonts}\n'
#                         '\t\t\t\t\\usepackage{amssymb}\n'
#                         '\t\t\t\t\\usepackage{amsbsy}\n'
#                         '\t\t\t\t\\usepackage{mathrsfs}\n'
#                         '\t\t\t\t\\usepackage{upgreek}\n'
#                         '\t\t\t\t\\setlength{\\oddsidemargin}{-69pt}\n'
#                         '\t\t\t\t\\begin{document}$$\\text '
#                         '{TeV}$$\\end{document}. The data were collected in '
#                         '2015 and 2016 by the ATLAS experiment at the Large '
#                         'Hadron Collider, and correspond to an integrated '
#                         'luminosity of 36.1fb-1\\documentclass[12pt]{minimal}\n'
#                         '\t\t\t\t\\usepackage{amsmath}\n'
#                         '\t\t\t\t\\usepackage{wasysym}\n'
#                         '\t\t\t\t\\usepackage{amsfonts}\n'
#                         '\t\t\t\t\\usepackage{amssymb}\n'
#                         '\t\t\t\t\\usepackage{amsbsy}\n'
#                         '\t\t\t\t\\usepackage{mathrsfs}\n'
#                         '\t\t\t\t\\usepackage{upgreek}\n'
#                         '\t\t\t\t\\setlength{\\oddsidemargin}{-69pt}\n'
#                         '\t\t\t\t\\begin{document}$$36.1~\\hbox '
#                         '{fb}^{-1}$$\\end{document}. The '
#                         'W±Z\\documentclass[12pt]{minimal}\n'
#                         '\t\t\t\t\\usepackage{amsmath}\n'
#                         '\t\t\t\t\\usepackage{wasysym}\n'
#                         '\t\t\t\t\\usepackage{amsfonts}\n'
#                         '\t\t\t\t\\usepackage{amssymb}\n'
#                         '\t\t\t\t\\usepackage{amsbsy}\n'
#                         '\t\t\t\t\\usepackage{mathrsfs}\n'
#                         '\t\t\t\t\\usepackage{upgreek}\n'
#                         '\t\t\t\t\\setlength{\\oddsidemargin}{-69pt}\n'
#                         '\t\t\t\t\\begin{document}$$W^{\\pm '
#                         '}Z$$\\end{document} candidate events are '
#                         'reconstructed using leptonic decay modes of the gauge '
#                         'bosons into electrons and muons. The measured '
#                         'inclusive cross section in the detector fiducial '
#                         'region for a single leptonic decay mode is '
#                         'σW±Z→ℓ′νℓℓfid.=63.7±1.0(stat.)±2.3(syst.)±1.4(lumi.)\\documentclass[12pt]{minimal}\n'
#                         '\t\t\t\t\\usepackage{amsmath}\n'
#                         '\t\t\t\t\\usepackage{wasysym}\n'
#                         '\t\t\t\t\\usepackage{amsfonts}\n'
#                         '\t\t\t\t\\usepackage{amssymb}\n'
#                         '\t\t\t\t\\usepackage{amsbsy}\n'
#                         '\t\t\t\t\\usepackage{mathrsfs}\n'
#                         '\t\t\t\t\\usepackage{upgreek}\n'
#                         '\t\t\t\t\\setlength{\\oddsidemargin}{-69pt}\n'
#                         '\t\t\t\t\\begin{document}$$\\sigma _{W^\\pm Z '
#                         "\\rightarrow \\ell ^{'} \\nu \\ell \\ell }^{\\text "
#                         '{fid.}} = 63.7 \\, \\pm ~1.0~\\text {(stat.)} \\, '
#                         '\\pm ~2.3~\\text {(syst.)} \\, \\pm ~1.4~\\text '
#                         '{(lumi.)}$$\\end{document}\xa0fb, reproduced by the '
#                         'next-to-next-to-leading-order Standard Model '
#                         'prediction of '
#                         '61.5-1.3+1.4\\documentclass[12pt]{minimal}\n'
#                         '\t\t\t\t\\usepackage{amsmath}\n'
#                         '\t\t\t\t\\usepackage{wasysym}\n'
#                         '\t\t\t\t\\usepackage{amsfonts}\n'
#                         '\t\t\t\t\\usepackage{amssymb}\n'
#                         '\t\t\t\t\\usepackage{amsbsy}\n'
#                         '\t\t\t\t\\usepackage{mathrsfs}\n'
#                         '\t\t\t\t\\usepackage{upgreek}\n'
#                         '\t\t\t\t\\setlength{\\oddsidemargin}{-69pt}\n'
#                         '\t\t\t\t'
#                         '\\begin{document}$$61.5^{+1.4}_{-1.3}$$\\end{document}\xa0'
#                         'fb. Cross sections for '
#                         'W+Z\\documentclass[12pt]{minimal}\n'
#                         '\t\t\t\t\\usepackage{amsmath}\n'
#                         '\t\t\t\t\\usepackage{wasysym}\n'
#                         '\t\t\t\t\\usepackage{amsfonts}\n'
#                         '\t\t\t\t\\usepackage{amssymb}\n'
#                         '\t\t\t\t\\usepackage{amsbsy}\n'
#                         '\t\t\t\t\\usepackage{mathrsfs}\n'
#                         '\t\t\t\t\\usepackage{upgreek}\n'
#                         '\t\t\t\t\\setlength{\\oddsidemargin}{-69pt}\n'
#                         '\t\t\t\t\\begin{document}$$W^+Z$$\\end{document} and '
#                         'W-Z\\documentclass[12pt]{minimal}\n'
#                         '\t\t\t\t\\usepackage{amsmath}\n'
#                         '\t\t\t\t\\usepackage{wasysym}\n'
#                         '\t\t\t\t\\usepackage{amsfonts}\n'
#                         '\t\t\t\t\\usepackage{amssymb}\n'
#                         '\t\t\t\t\\usepackage{amsbsy}\n'
#                         '\t\t\t\t\\usepackage{mathrsfs}\n'
#                         '\t\t\t\t\\usepackage{upgreek}\n'
#                         '\t\t\t\t\\setlength{\\oddsidemargin}{-69pt}\n'
#                         '\t\t\t\t\\begin{document}$$W^-Z$$\\end{document} '
#                         'production and their ratio are presented as well as '
#                         'differential cross sections for several kinematic '
#                         'observables. An analysis of angular distributions of '
#                         'leptons from decays of W and Z bosons is performed '
#                         'for the first time in pair-produced events in '
#                         'hadronic collisions, and integrated helicity '
#                         'fractions in the detector fiducial region are '
#                         'measured for the W and Z bosons separately. Of '
#                         'particular interest, the longitudinal helicity '
#                         'fraction of pair-produced vector bosons is also '
#                         'measured.'}],
#  'journal': {'title': 'The European Physical Journal C', 'year': '2019'},
#  'lang_code': ['eng'],
#  'primary_id': {'id': 's10052-019-7027-6', 'type': 'SPRINGER'},
#  'title': 'Measurement of W±Z\\documentclass[12pt]{minimal}\n'
#           '\t\t\t\t\\usepackage{amsmath}\n'
#           '\t\t\t\t\\usepackage{wasysym}\n'
#           '\t\t\t\t\\usepackage{amsfonts}\n'
#           '\t\t\t\t\\usepackage{amssymb}\n'
#           '\t\t\t\t\\usepackage{amsbsy}\n'
#           '\t\t\t\t\\usepackage{mathrsfs}\n'
#           '\t\t\t\t\\usepackage{upgreek}\n'
#           '\t\t\t\t\\setlength{\\oddsidemargin}{-69pt}\n'
#           '\t\t\t\t\\begin{document}$$W^{\\pm }Z$$\\end{document} production '
#           'cross sections and gauge boson polarisation in pp collisions at '
#           's=13TeV\\documentclass[12pt]{minimal}\n'
#           '\t\t\t\t\\usepackage{amsmath}\n'
#           '\t\t\t\t\\usepackage{wasysym}\n'
#           '\t\t\t\t\\usepackage{amsfonts}\n'
#           '\t\t\t\t\\usepackage{amssymb}\n'
#           '\t\t\t\t\\usepackage{amsbsy}\n'
#           '\t\t\t\t\\usepackage{mathrsfs}\n'
#           '\t\t\t\t\\usepackage{upgreek}\n'
#           '\t\t\t\t\\setlength{\\oddsidemargin}{-69pt}\n'
#           '\t\t\t\t\\begin{document}$$\\sqrt{s} = 13~\\text '
#           '{TeV}$$\\end{document} with the ATLAS detector'}
# ### Measurement of W±Z\documentclass[12pt]{minimal}
# 				\usepackage{amsmath}
# 				\usepackage{wasysym}
# 				\usepackage{amsfonts}
# 				\usepackage{amssymb}
# 				\usepackage{amsbsy}
# 				\usepackage{mathrsfs}
# 				\usepackage{upgreek}
# 				\setlength{\oddsidemargin}{-69pt}
# 				\begin{document}$$W^{\pm }Z$$\end{document} production cross sections and gauge boson polarisation in pp collisions at s=13TeV\documentclass[12pt]{minimal}
# 				\usepackage{amsmath}
# 				\usepackage{wasysym}
# 				\usepackage{amsfonts}
# 				\usepackage{amssymb}
# 				\usepackage{amsbsy}
# 				\usepackage{mathrsfs}
# 				\usepackage{upgreek}
# 				\setlength{\oddsidemargin}{-69pt}
# 				\begin{document}$$\sqrt{s} = 13~\text {TeV}$$\end{document} with the ATLAS detector
#
# Zeitschrift: The European Physical Journal C (2019)
#
# Abstract
#
# This paper presents measurements of W±Z\documentclass[12pt]{minimal}
# 				\usepackage{amsmath}
# 				\usepackage{wasysym}
# 				\usepackage{amsfonts}
# 				\usepackage{amssymb}
# 				\usepackage{amsbsy}
# 				\usepackage{mathrsfs}
# 				\usepackage{upgreek}
# 				\setlength{\oddsidemargin}{-69pt}
# 				\begin{document}$$W^{\pm }Z$$\end{document} production cross sections in pp collisions at a centre-of-mass energy of 13 TeV\documentclass[12pt]{minimal}
# 				\usepackage{amsmath}
# 				\usepackage{wasysym}
# 				\usepackage{amsfonts}
# 				\usepackage{amssymb}
# 				\usepackage{amsbsy}
# 				\usepackage{mathrsfs}
# 				\usepackage{upgreek}
# 				\setlength{\oddsidemargin}{-69pt}
# 				\begin{document}$$\text {TeV}$$\end{document}. The data were collected in 2015 and 2016 by the ATLAS experiment at the Large Hadron Collider, and correspond to an integrated luminosity of 36.1fb-1\documentclass[12pt]{minimal}
# 				\usepackage{amsmath}
# 				\usepackage{wasysym}
# 				\usepackage{amsfonts}
# 				\usepackage{amssymb}
# 				\usepackage{amsbsy}
# 				\usepackage{mathrsfs}
# 				\usepackage{upgreek}
# 				\setlength{\oddsidemargin}{-69pt}
# 				\begin{document}$$36.1~\hbox {fb}^{-1}$$\end{document}. The W±Z\documentclass[12pt]{minimal}
# 				\usepackage{amsmath}
# 				\usepackage{wasysym}
# 				\usepackage{amsfonts}
# 				\usepackage{amssymb}
# 				\usepackage{amsbsy}
# 				\usepackage{mathrsfs}
# 				\usepackage{upgreek}
# 				\setlength{\oddsidemargin}{-69pt}
# 				\begin{document}$$W^{\pm }Z$$\end{document} candidate events are reconstructed using leptonic decay modes of the gauge bosons into electrons and muons. The measured inclusive cross section in the detector fiducial region for a single leptonic decay mode is σW±Z→ℓ′νℓℓfid.=63.7±1.0(stat.)±2.3(syst.)±1.4(lumi.)\documentclass[12pt]{minimal}
# 				\usepackage{amsmath}
# 				\usepackage{wasysym}
# 				\usepackage{amsfonts}
# 				\usepackage{amssymb}
# 				\usepackage{amsbsy}
# 				\usepackage{mathrsfs}
# 				\usepackage{upgreek}
# 				\setlength{\oddsidemargin}{-69pt}
# 				\begin{document}$$\sigma _{W^\pm Z \rightarrow \ell ^{'} \nu \ell \ell }^{\text {fid.}} = 63.7 \, \pm ~1.0~\text {(stat.)} \, \pm ~2.3~\text {(syst.)} \, \pm ~1.4~\text {(lumi.)}$$\end{document} fb, reproduced by the next-to-next-to-leading-order Standard Model prediction of 61.5-1.3+1.4\documentclass[12pt]{minimal}
# 				\usepackage{amsmath}
# 				\usepackage{wasysym}
# 				\usepackage{amsfonts}
# 				\usepackage{amssymb}
# 				\usepackage{amsbsy}
# 				\usepackage{mathrsfs}
# 				\usepackage{upgreek}
# 				\setlength{\oddsidemargin}{-69pt}
# 				\begin{document}$$61.5^{+1.4}_{-1.3}$$\end{document} fb. Cross sections for W+Z\documentclass[12pt]{minimal}
# 				\usepackage{amsmath}
# 				\usepackage{wasysym}
# 				\usepackage{amsfonts}
# 				\usepackage{amssymb}
# 				\usepackage{amsbsy}
# 				\usepackage{mathrsfs}
# 				\usepackage{upgreek}
# 				\setlength{\oddsidemargin}{-69pt}
# 				\begin{document}$$W^+Z$$\end{document} and W-Z\documentclass[12pt]{minimal}
# 				\usepackage{amsmath}
# 				\usepackage{wasysym}
# 				\usepackage{amsfonts}
# 				\usepackage{amssymb}
# 				\usepackage{amsbsy}
# 				\usepackage{mathrsfs}
# 				\usepackage{upgreek}
# 				\setlength{\oddsidemargin}{-69pt}
# 				\begin{document}$$W^-Z$$\end{document} production and their ratio are presented as well as differential cross sections for several kinematic observables. An analysis of angular distributions of leptons from decays of W and Z bosons is performed for the first time in pair-produced events in hadronic collisions, and integrated helicity fractions in the detector fiducial region are measured for the W and Z bosons separately. Of particular interest, the longitudinal helicity fraction of pair-produced vector bosons is also measured.

# %% [markdown]
# ## Vollständige Konvertierung eines Springer Artikels
#
# In diesem Beispiel wird der Konverter aus dem vzg.jconv Modul benutzt.

# %%
from vzg.jconv.converter.jats import JatsConverter
from vzg.jconv.converter.jats import JatsArticle

def springer_article():
    if not xmlpath.exists():
        print("Datei existiert nicht. {}".format(xmlpath.name))
        return None

    print("{} wird bearbeitet\n".format(xmlpath.name))
    
    jconv = JatsConverter(xmlpath, validate=True)
    jconv.run()
    
    anum = len(jconv.articles)
    msg = f"Die Datei beinhaltet {anum} Artikel.\n"
    print(msg)
    
    title = ""
    abstract = ""
    
    if len(jconv.articles) > 0:
        return jconv.articles[0]
    
    return None

# Konvertierung mit Validierung starten
article = springer_article()

mdtext = ""

if isinstance(article, JatsArticle):
    
    # Das erzeugte Python Dictionary anzeigen
    pprint(article.jdict)
    
    # Die konvertierten Daten als JSON Datei abspeichern
    with open("article-complete.json", "w") as jfh:
        json.dump(article.jdict, jfh)
        
    mdtext = """### {}

Zeitschrift: {} ({})
""".format(article.jdict['title'].replace("$$", "$"), 
           article.jdict["journal"]["title"], 
           article.jdict["journal"]["year"])
    
    if len(article.jdict['abstracts']) > 0:
        abstract = article.jdict['abstracts'][0]['text']
        mdtext += """\n{}""".format(abstract.replace("$$", "$"))

# Die Daten aus der Konvertierung benutzen, um diese formatiert anzuzeigen 
Markdown(mdtext)
# Out:
# article.xml wird bearbeitet
#
# Die Datei beinhaltet 1 Artikel.
#
# {'abstracts': [{'lang_code': 'eng',
#                 'text': 'Abstract\n'
#                         '\n'
#                         'This paper presents measurements of $$W^{\\pm }Z$$ '
#                         'production cross sections in pp collisions at a '
#                         'centre-of-mass energy of 13\xa0$$\\text {TeV}$$. The '
#                         'data were collected in 2015 and 2016 by the ATLAS '
#                         'experiment at the Large Hadron Collider, and '
#                         'correspond to an integrated luminosity of '
#                         '$$36.1~\\hbox {fb}^{-1}$$. The $$W^{\\pm }Z$$ '
#                         'candidate events are reconstructed using leptonic '
#                         'decay modes of the gauge bosons into electrons and '
#                         'muons. The measured inclusive cross section in the '
#                         'detector fiducial region for a single leptonic decay '
#                         "mode is $$\\sigma _{W^\\pm Z \\rightarrow \\ell ^{'} "
#                         '\\nu \\ell \\ell }^{\\text {fid.}} = 63.7 \\, \\pm '
#                         '~1.0~\\text {(stat.)} \\, \\pm ~2.3~\\text {(syst.)} '
#                         '\\, \\pm ~1.4~\\text {(lumi.)}$$\xa0fb, reproduced by '
#                         'the next-to-next-to-leading-order Standard Model '
#                         'prediction of $$61.5^{+1.4}_{-1.3}$$\xa0fb. Cross '
#                         'sections for $$W^+Z$$ and $$W^-Z$$ production and '
#                         'their ratio are presented as well as differential '
#                         'cross sections for several kinematic observables. An '
#                         'analysis of angular distributions of leptons from '
#                         'decays of W and Z bosons is performed for the first '
#                         'time in pair-produced events in hadronic collisions, '
#                         'and integrated helicity fractions in the detector '
#                         'fiducial region are measured for the W and Z bosons '
#                         'separately. Of particular interest, the longitudinal '
#                         'helicity fraction of pair-produced vector bosons is '
#                         'also measured.'}],
#  'copyright': '© CERN for the benefit of the ATLAS collaboration 2019',
#  'journal': {'day': '22',
#              'issue': '6',
#              'journal_ids': [{'id': '10052', 'type': 'springer'},
#                              {'id': '10.1007/10052.1434-6052', 'type': 'doi'},
#                              {'id': '1434-6052', 'type': 'eissn'}],
#              'month': '06',
#              'publisher': {'name': 'Springer Berlin Heidelberg',
#                            'place': 'Berlin/Heidelberg'},
#              'title': 'The European Physical Journal C',
#              'volume': '79',
#              'year': '2019'},
#  'lang_code': ['eng'],
#  'other_ids': [{'id': '10.1140/epjc/s10052-019-7027-6', 'type': 'doi'}],
#  'persons': [{'affiliation': {'affiliation_ids': [{'id': '0000 0004 1772 8348',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.410890.4',
#                                                    'type': 'GRID'}],
#                               'name': 'Université Mohamed Premier and LPTPM'},
#               'firstname': 'M.',
#               'fullname': 'M. Aaboud',
#               'lastname': 'Aaboud',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 0452 0652',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.470046.1',
#                                                    'type': 'GRID'}],
#                               'name': 'CPPM, Aix-Marseille Université, '
#                                       'CNRS/IN2P3'},
#               'firstname': 'G.',
#               'fullname': 'G. Aad',
#               'lastname': 'Aad',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 0447 0018',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.266900.b',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Oklahoma'},
#               'firstname': 'B.',
#               'fullname': 'B. Abbott',
#               'lastname': 'Abbott',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 7304',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.1010.0',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Adelaide'},
#               'firstname': 'O.',
#               'fullname': 'O. Abdinov',
#               'lastname': 'Abdinov',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 4910 6535',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.460789.4',
#                                                    'type': 'GRID'}],
#                               'name': 'Université Paris-Saclay'},
#               'firstname': 'B.',
#               'fullname': 'B. Abeloos',
#               'lastname': 'Abeloos',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2188 881X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.4970.a',
#                                                    'type': 'GRID'}],
#                               'name': 'Royal Holloway University of London'},
#               'firstname': 'D. K.',
#               'fullname': 'D. K. Abhayasinghe',
#               'lastname': 'Abhayasinghe',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2157 2938',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.17063.33',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Toronto'},
#               'firstname': 'S. H.',
#               'fullname': 'S. H. Abidi',
#               'lastname': 'Abidi',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 0674 042X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.5254.6',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Copenhagen'},
#               'firstname': 'O. S.',
#               'fullname': 'O. S. AbouZeid',
#               'lastname': 'AbouZeid',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 7590',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.12082.39',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Sussex'},
#               'firstname': 'N. L.',
#               'fullname': 'N. L. Abraham',
#               'lastname': 'Abraham',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1937 0546',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.12136.37',
#                                                    'type': 'GRID'}],
#                               'name': 'Tel Aviv University'},
#               'firstname': 'H.',
#               'fullname': 'H. Abramowicz',
#               'lastname': 'Abramowicz',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000121102151',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.6451.6',
#                                                    'type': 'GRID'}],
#                               'name': 'Israel Institute of Technology'},
#               'firstname': 'H.',
#               'fullname': 'H. Abreu',
#               'lastname': 'Abreu',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 1939 4845',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.187073.a',
#                                                    'type': 'GRID'}],
#                               'name': 'Argonne National Laboratory'},
#               'firstname': 'Y.',
#               'fullname': 'Y. Abulaiti',
#               'lastname': 'Abulaiti',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1760 7175',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.470223.0',
#                                                    'type': 'GRID'}],
#                               'name': 'INFN Gruppo Collegato di Udine, Sezione '
#                                       'di Trieste'},
#               'firstname': 'B. S.',
#               'fullname': 'B. S. Acharya',
#               'lastname': 'Acharya',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2151 536X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.26999.3d',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Tokyo'},
#               'firstname': 'S.',
#               'fullname': 'S. Adachi',
#               'lastname': 'Adachi',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 1941 7111',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.5802.f',
#                                                    'type': 'GRID'}],
#                               'name': 'Universität Mainz'},
#               'firstname': 'L.',
#               'fullname': 'L. Adam',
#               'lastname': 'Adam',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 4910 6535',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.460789.4',
#                                                    'type': 'GRID'}],
#                               'name': 'Université Paris-Saclay'},
#               'firstname': 'C.',
#               'fullname': 'C. Adam Bourdarios',
#               'lastname': 'Adam Bourdarios',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0000 9174 1488',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.9922.0',
#                                                    'type': 'GRID'}],
#                               'name': 'Faculty of Physics and Applied Computer '
#                                       'Science'},
#               'firstname': 'L.',
#               'fullname': 'L. Adamczyk',
#               'lastname': 'Adamczyk',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0000 9003 8934',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.261128.e',
#                                                    'type': 'GRID'}],
#                               'name': 'Northern Illinois University'},
#               'firstname': 'J.',
#               'fullname': 'J. Adelman',
#               'lastname': 'Adelman',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 973X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.5252.0',
#                                                    'type': 'GRID'}],
#                               'name': 'Ludwig-Maximilians-Universität München'},
#               'firstname': 'M.',
#               'fullname': 'M. Adersberger',
#               'lastname': 'Adersberger',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2253 9056',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.11220.30',
#                                                    'type': 'GRID'}],
#                               'name': 'Bogazici University'},
#               'firstname': 'A.',
#               'fullname': 'A. Adiguzel',
#               'lastname': 'Adiguzel',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2296 6998',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.76978.37',
#                                                    'type': 'GRID'}],
#                               'name': 'Rutherford Appleton Laboratory'},
#               'firstname': 'T.',
#               'fullname': 'T. Adye',
#               'lastname': 'Adye',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 0740 6917',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.205975.c',
#                                                    'type': 'GRID'}],
#                               'name': 'University of California Santa Cruz'},
#               'firstname': 'A. A.',
#               'fullname': 'A. A. Affolder',
#               'lastname': 'Affolder',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000121102151',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.6451.6',
#                                                    'type': 'GRID'}],
#                               'name': 'Israel Institute of Technology'},
#               'firstname': 'Y.',
#               'fullname': 'Y. Afik',
#               'lastname': 'Afik',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000419371784',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.8168.7',
#                                                    'type': 'GRID'}],
#                               'name': 'Alexandru Ioan Cuza University of Iasi'},
#               'firstname': 'C.',
#               'fullname': 'C. Agheorghiesei',
#               'lastname': 'Agheorghiesei',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': 'grid.420929.4',
#                                                    'type': 'GRID'}],
#                               'name': 'Laboratório de Instrumentação e Física '
#                                       'Experimental de Partículas-LIP'},
#               'firstname': 'J. A.',
#               'fullname': 'J. A. Aguilar-Saavedra',
#               'lastname': 'Aguilar-Saavedra',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000406204119',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.33762.33',
#                                                    'type': 'GRID'}],
#                               'name': 'Joint Institute for Nuclear Research'},
#               'firstname': 'F.',
#               'fullname': 'F. Ahmadov',
#               'lastname': 'Ahmadov',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': 'grid.470219.9',
#                                                    'type': 'GRID'}],
#                               'name': 'INFN Sezione di Roma Tor Vergata'},
#               'firstname': 'G.',
#               'fullname': 'G. Aielli',
#               'lastname': 'Aielli',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 0372 2033',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.258799.8',
#                                                    'type': 'GRID'}],
#                               'name': 'Kyoto University'},
#               'firstname': 'S.',
#               'fullname': 'S. Akatsuka',
#               'lastname': 'Akatsuka',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 0930 2361',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.4514.4',
#                                                    'type': 'GRID'}],
#                               'name': 'Lunds universitet'},
#               'firstname': 'T. P. A.',
#               'fullname': 'T. P. A. Åkesson',
#               'lastname': 'Åkesson',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2322 4988',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.8591.5',
#                                                    'type': 'GRID'}],
#                               'name': 'Université de Genève'},
#               'firstname': 'E.',
#               'fullname': 'E. Akilli',
#               'lastname': 'Akilli',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 0656 6476',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.425806.d',
#                                                    'type': 'GRID'}],
#                               'name': 'P.N. Lebedev Physical Institute of the '
#                                       'Russian Academy of Sciences'},
#               'firstname': 'A. V.',
#               'fullname': 'A. V. Akimov',
#               'lastname': 'Akimov',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1757 1758',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.6292.f',
#                                                    'type': 'GRID'}],
#                               'name': 'INFN Bologna and Universita’ di '
#                                       'Bologna'},
#               'firstname': 'G. L.',
#               'fullname': 'G. L. Alberghi',
#               'lastname': 'Alberghi',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 9465',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.143640.4',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Victoria'},
#               'firstname': 'J.',
#               'fullname': 'J. Albert',
#               'lastname': 'Albert',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 0648 0236',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.463190.9',
#                                                    'type': 'GRID'}],
#                               'name': 'INFN e Laboratori Nazionali di '
#                                       'Frascati'},
#               'firstname': 'P.',
#               'fullname': 'P. Albicocco',
#               'lastname': 'Albicocco',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2097 3940',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.9499.d',
#                                                    'type': 'GRID'}],
#                               'name': 'Universidad Nacional de La Plata and '
#                                       'CONICET'},
#               'firstname': 'M. J.',
#               'fullname': 'M. J. Alconada Verzini',
#               'lastname': 'Alconada Verzini',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000122931605',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.5590.9',
#                                                    'type': 'GRID'}],
#                               'name': 'Radboud University Nijmegen/Nikhef'},
#               'firstname': 'S.',
#               'fullname': 'S. Alderweireldt',
#               'lastname': 'Alderweireldt',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2156 142X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.9132.9',
#                                                    'type': 'GRID'}],
#                               'name': 'CERN'},
#               'firstname': 'M.',
#               'fullname': 'M. Aleksa',
#               'lastname': 'Aleksa',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000406204119',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.33762.33',
#                                                    'type': 'GRID'}],
#                               'name': 'Joint Institute for Nuclear Research'},
#               'firstname': 'I. N.',
#               'fullname': 'I. N. Aleksandrov',
#               'lastname': 'Aleksandrov',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0000 9463 5349',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.443874.8',
#                                                    'type': 'GRID'}],
#                               'name': 'Horia Hulubei National Institute of '
#                                       'Physics and Nuclear Engineering'},
#               'firstname': 'C.',
#               'fullname': 'C. Alexa',
#               'lastname': 'Alexa',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2185 9808',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.4241.3',
#                                                    'type': 'GRID'}],
#                               'name': 'National Technical University of '
#                                       'Athens'},
#               'firstname': 'T.',
#               'fullname': 'T. Alexopoulos',
#               'lastname': 'Alexopoulos',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 0447 0018',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.266900.b',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Oklahoma'},
#               'firstname': 'M.',
#               'fullname': 'M. Alhroob',
#               'lastname': 'Alhroob',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000121738213',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.6652.7',
#                                                    'type': 'GRID'}],
#                               'name': 'Czech Technical University in Prague'},
#               'firstname': 'B.',
#               'fullname': 'B. Ali',
#               'lastname': 'Ali',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': 'grid.470206.7',
#                                                    'type': 'GRID'}],
#                               'name': 'INFN Sezione di Milano'},
#               'firstname': 'G.',
#               'fullname': 'G. Alimonti',
#               'lastname': 'Alimonti',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 7822',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.170205.1',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Chicago'},
#               'firstname': 'J.',
#               'fullname': 'J. Alison',
#               'lastname': 'Alison',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000122986657',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.34477.33',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Washington'},
#               'firstname': 'S. P.',
#               'fullname': 'S. P. Alkire',
#               'lastname': 'Alkire',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 4910 6535',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.460789.4',
#                                                    'type': 'GRID'}],
#                               'name': 'Université Paris-Saclay'},
#               'firstname': 'C.',
#               'fullname': 'C. Allaire',
#               'lastname': 'Allaire',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 7590',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.12082.39',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Sussex'},
#               'firstname': 'B. M. M.',
#               'fullname': 'B. M. M. Allbrooke',
#               'lastname': 'Allbrooke',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 8008',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.170202.6',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Oregon'},
#               'firstname': 'B. W.',
#               'fullname': 'B. W. Allen',
#               'lastname': 'Allen',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 7486',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.6572.6',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Birmingham'},
#               'firstname': 'P. P.',
#               'fullname': 'P. P. Allport',
#               'lastname': 'Allport',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': 'grid.470211.1',
#                                                    'type': 'GRID'}],
#                               'name': 'INFN Sezione di Napoli'},
#               'firstname': 'A.',
#               'fullname': 'A. Aloisio',
#               'lastname': 'Aloisio',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 0674 042X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.5254.6',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Copenhagen'},
#               'firstname': 'A.',
#               'fullname': 'A. Alonso',
#               'lastname': 'Alonso',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2097 3940',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.9499.d',
#                                                    'type': 'GRID'}],
#                               'name': 'Universidad Nacional de La Plata and '
#                                       'CONICET'},
#               'firstname': 'F.',
#               'fullname': 'F. Alonso',
#               'lastname': 'Alonso',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000122986657',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.34477.33',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Washington'},
#               'firstname': 'C.',
#               'fullname': 'C. Alpigiani',
#               'lastname': 'Alpigiani',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2193 314X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.8756.c',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Glasgow'},
#               'firstname': 'A. A.',
#               'fullname': 'A. A. Alshehri',
#               'lastname': 'Alshehri',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 0452 0652',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.470046.1',
#                                                    'type': 'GRID'}],
#                               'name': 'CPPM, Aix-Marseille Université, '
#                                       'CNRS/IN2P3'},
#               'firstname': 'M. I.',
#               'fullname': 'M. I. Alstaty',
#               'lastname': 'Alstaty',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2156 142X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.9132.9',
#                                                    'type': 'GRID'}],
#                               'name': 'CERN'},
#               'firstname': 'B.',
#               'fullname': 'B. Alvarez Gonzalez',
#               'lastname': 'Alvarez Gonzalez',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2173 938X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.5338.d',
#                                                    'type': 'GRID'}],
#                               'name': 'Centro Mixto Universidad de Valencia - '
#                                       'CSIC'},
#               'firstname': 'D.',
#               'fullname': 'D. Álvarez Piqueras',
#               'lastname': 'Álvarez Piqueras',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': 'grid.470211.1',
#                                                    'type': 'GRID'}],
#                               'name': 'INFN Sezione di Napoli'},
#               'firstname': 'M. G.',
#               'fullname': 'M. G. Alviggi',
#               'lastname': 'Alviggi',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2231 4551',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.184769.5',
#                                                    'type': 'GRID'}],
#                               'name': 'Lawrence Berkeley National Laboratory '
#                                       'and University of California'},
#               'firstname': 'B. T.',
#               'fullname': 'B. T. Amadio',
#               'lastname': 'Amadio',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2294 473X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.8536.8',
#                                                    'type': 'GRID'}],
#                               'name': 'Universidade Federal do Rio De Janeiro '
#                                       'COPPE/EE/IF'},
#               'firstname': 'Y.',
#               'fullname': 'Y. Amaral Coutinho',
#               'lastname': 'Amaral Coutinho',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 8649',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.14709.3b',
#                                                    'type': 'GRID'}],
#                               'name': 'McGill University'},
#               'firstname': 'A.',
#               'fullname': 'A. Ambler',
#               'lastname': 'Ambler',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 8948',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.4991.5',
#                                                    'type': 'GRID'}],
#                               'name': 'Oxford University'},
#               'firstname': 'L.',
#               'fullname': 'L. Ambroz',
#               'lastname': 'Ambroz',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 9473',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.253264.4',
#                                                    'type': 'GRID'}],
#                               'name': 'Brandeis University'},
#               'firstname': 'C.',
#               'fullname': 'C. Amelung',
#               'lastname': 'Amelung',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000086837370',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.214458.e',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Michigan'},
#               'firstname': 'D.',
#               'fullname': 'D. Amidei',
#               'lastname': 'Amidei',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': 'grid.420929.4',
#                                                    'type': 'GRID'}],
#                               'name': 'Laboratório de Instrumentação e Física '
#                                       'Experimental de Partículas-LIP'},
#               'firstname': 'S. P.',
#               'fullname': 'S. P. Amor Dos Santos',
#               'lastname': 'Amor Dos Santos',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 0492 0453',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.7683.a',
#                                                    'type': 'GRID'}],
#                               'name': 'Deutsches Elektronen-Synchrotron DESY'},
#               'firstname': 'S.',
#               'fullname': 'S. Amoroso',
#               'lastname': 'Amoroso',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2322 4988',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.8591.5',
#                                                    'type': 'GRID'}],
#                               'name': 'Université de Genève'},
#               'firstname': 'C. S.',
#               'fullname': 'C. S. Amrouche',
#               'lastname': 'Amrouche',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 9262',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.11835.3e',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Sheffield'},
#               'firstname': 'C.',
#               'fullname': 'C. Anastopoulos',
#               'lastname': 'Anastopoulos',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2322 4988',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.8591.5',
#                                                    'type': 'GRID'}],
#                               'name': 'Université de Genève'},
#               'firstname': 'L. S.',
#               'fullname': 'L. S. Ancu',
#               'lastname': 'Ancu',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [],
#                               'name': 'IRFU, CEA, Université Paris-Saclay'},
#               'firstname': 'N.',
#               'fullname': 'N. Andari',
#               'lastname': 'Andari',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 9924',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.89336.37',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Texas at Austin'},
#               'firstname': 'T.',
#               'fullname': 'T. Andeen',
#               'lastname': 'Andeen',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2190 4373',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.7700.0',
#                                                    'type': 'GRID'}],
#                               'name': 'Ruprecht-Karls-Universität Heidelberg'},
#               'firstname': 'C. F.',
#               'fullname': 'C. F. Anders',
#               'lastname': 'Anders',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 0726 5157',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.5734.5',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Bern'},
#               'firstname': 'J. K.',
#               'fullname': 'J. K. Anders',
#               'lastname': 'Anders',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 7822',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.170205.1',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Chicago'},
#               'firstname': 'K. J.',
#               'fullname': 'K. J. Anderson',
#               'lastname': 'Anderson',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': 'grid.470206.7',
#                                                    'type': 'GRID'}],
#                               'name': 'INFN Sezione di Milano'},
#               'firstname': 'A.',
#               'fullname': 'A. Andreazza',
#               'lastname': 'Andreazza',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2190 4373',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.7700.0',
#                                                    'type': 'GRID'}],
#                               'name': 'Ruprecht-Karls-Universität Heidelberg'},
#               'firstname': 'V.',
#               'fullname': 'V. Andrei',
#               'lastname': 'Andrei',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 9465',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.143640.4',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Victoria'},
#               'firstname': 'C. R.',
#               'fullname': 'C. R. Anelli',
#               'lastname': 'Anelli',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000115480420',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.494717.8',
#                                                    'type': 'GRID'}],
#                               'name': 'LPC, Université Clermont Auvergne, '
#                                       'CNRS/IN2P3'},
#               'firstname': 'S.',
#               'fullname': 'S. Angelidakis',
#               'lastname': 'Angelidakis',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 0646 2193',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.420012.5',
#                                                    'type': 'GRID'}],
#                               'name': 'Nikhef National Institute for Subatomic '
#                                       'Physics and University of Amsterdam'},
#               'firstname': 'I.',
#               'fullname': 'I. Angelozzi',
#               'lastname': 'Angelozzi',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000419368729',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.21729.3f',
#                                                    'type': 'GRID'}],
#                               'name': 'Columbia University'},
#               'firstname': 'A.',
#               'fullname': 'A. Angerami',
#               'lastname': 'Angerami',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2254 1834',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.415877.8',
#                                                    'type': 'GRID'}],
#                               'name': 'Budker Institute of Nuclear Physics and '
#                                       'NSU, SB RAS'},
#               'firstname': 'A. V.',
#               'fullname': 'A. V. Anisenkov',
#               'lastname': 'Anisenkov',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': 'grid.470216.6',
#                                                    'type': 'GRID'}],
#                               'name': 'INFN Sezione di Pisa'},
#               'firstname': 'A.',
#               'fullname': 'A. Annovi',
#               'lastname': 'Annovi',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2190 4373',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.7700.0',
#                                                    'type': 'GRID'}],
#                               'name': 'Ruprecht-Karls-Universität Heidelberg'},
#               'firstname': 'C.',
#               'fullname': 'C. Antel',
#               'lastname': 'Antel',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 9262',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.11835.3e',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Sheffield'},
#               'firstname': 'M. T.',
#               'fullname': 'M. T. Anthony',
#               'lastname': 'Anthony',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 0648 0236',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.463190.9',
#                                                    'type': 'GRID'}],
#                               'name': 'INFN e Laboratori Nazionali di '
#                                       'Frascati'},
#               'firstname': 'M.',
#               'fullname': 'M. Antonelli',
#               'lastname': 'Antonelli',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 0668 7243',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.266093.8',
#                                                    'type': 'GRID'}],
#                               'name': 'University of California Irvine'},
#               'firstname': 'D. J. A.',
#               'fullname': 'D. J. A. Antrim',
#               'lastname': 'Antrim',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': 'grid.470218.8',
#                                                    'type': 'GRID'}],
#                               'name': 'INFN Sezione di Roma'},
#               'firstname': 'F.',
#               'fullname': 'F. Anulli',
#               'lastname': 'Anulli',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2155 959X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.410794.f',
#                                                    'type': 'GRID'}],
#                               'name': 'KEK, High Energy Accelerator Research '
#                                       'Organization'},
#               'firstname': 'M.',
#               'fullname': 'M. Aoki',
#               'lastname': 'Aoki',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2173 938X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.5338.d',
#                                                    'type': 'GRID'}],
#                               'name': 'Centro Mixto Universidad de Valencia - '
#                                       'CSIC'},
#               'firstname': 'J. A.',
#               'fullname': 'J. A. Aparisi Pozo',
#               'lastname': 'Aparisi Pozo',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2156 142X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.9132.9',
#                                                    'type': 'GRID'}],
#                               'name': 'CERN'},
#               'firstname': 'L.',
#               'fullname': 'L. Aperio Bella',
#               'lastname': 'Aperio Bella',
# ...
#                                                    'type': 'GRID'}],
#                               'name': 'University of Wisconsin'},
#               'firstname': 'C.',
#               'fullname': 'C. Zhou',
#               'lastname': 'Zhou',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 7929',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.263864.d',
#                                                    'type': 'GRID'}],
#                               'name': 'Southern Methodist University'},
#               'firstname': 'L.',
#               'fullname': 'L. Zhou',
#               'lastname': 'Zhou',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000119573309',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.9227.e',
#                                                    'type': 'GRID'}],
#                               'name': 'Chinese Academy of Sciences'},
#               'firstname': 'M. S.',
#               'fullname': 'M. S. Zhou',
#               'lastname': 'Zhou',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2216 9681',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.36425.36',
#                                                    'type': 'GRID'}],
#                               'name': 'Stony Brook University'},
#               'firstname': 'M.',
#               'fullname': 'M. Zhou',
#               'lastname': 'Zhou',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 0368 8293',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.16821.3c',
#                                                    'type': 'GRID'}],
#                               'name': 'Shanghai Jiao Tong University, '
#                                       'KLPPAC-MoE, SKLPPC'},
#               'firstname': 'N.',
#               'fullname': 'N. Zhou',
#               'lastname': 'Zhou',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2168 186X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.134563.6',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Arizona'},
#               'firstname': 'Y.',
#               'fullname': 'Y. Zhou',
#               'lastname': 'Zhou',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1761 1174',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.27255.37',
#                                                    'type': 'GRID'}],
#                               'name': 'Shandong University'},
#               'firstname': 'C. G.',
#               'fullname': 'C. G. Zhu',
#               'lastname': 'Zhu',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000121679639',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.59053.3a',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Science and Technology of '
#                                       'China'},
#               'firstname': 'H. L.',
#               'fullname': 'H. L. Zhu',
#               'lastname': 'Zhu',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000119573309',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.9227.e',
#                                                    'type': 'GRID'}],
#                               'name': 'Chinese Academy of Sciences'},
#               'firstname': 'H.',
#               'fullname': 'H. Zhu',
#               'lastname': 'Zhu',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000086837370',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.214458.e',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Michigan'},
#               'firstname': 'J.',
#               'fullname': 'J. Zhu',
#               'lastname': 'Zhu',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000121679639',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.59053.3a',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Science and Technology of '
#                                       'China'},
#               'firstname': 'Y.',
#               'fullname': 'Y. Zhu',
#               'lastname': 'Zhu',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000119573309',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.9227.e',
#                                                    'type': 'GRID'}],
#                               'name': 'Chinese Academy of Sciences'},
#               'firstname': 'X.',
#               'fullname': 'X. Zhuang',
#               'lastname': 'Zhuang',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 0656 6476',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.425806.d',
#                                                    'type': 'GRID'}],
#                               'name': 'P.N. Lebedev Physical Institute of the '
#                                       'Russian Academy of Sciences'},
#               'firstname': 'K.',
#               'fullname': 'K. Zhukov',
#               'lastname': 'Zhukov',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2254 1834',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.415877.8',
#                                                    'type': 'GRID'}],
#                               'name': 'Budker Institute of Nuclear Physics and '
#                                       'NSU, SB RAS'},
#               'firstname': 'V.',
#               'fullname': 'V. Zhulanov',
#               'lastname': 'Zhulanov',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 1958 8658',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.8379.5',
#                                                    'type': 'GRID'}],
#                               'name': 'Julius-Maximilians-Universität '
#                                       'Würzburg'},
#               'firstname': 'A.',
#               'fullname': 'A. Zibell',
#               'lastname': 'Zibell',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 0790 959X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.411377.7',
#                                                    'type': 'GRID'}],
#                               'name': 'Indiana University'},
#               'firstname': 'D.',
#               'fullname': 'D. Zieminska',
#               'lastname': 'Zieminska',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000000406204119',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.33762.33',
#                                                    'type': 'GRID'}],
#                               'name': 'Joint Institute for Nuclear Research'},
#               'firstname': 'N. I.',
#               'fullname': 'N. I. Zimine',
#               'lastname': 'Zimine',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': 'grid.5963.9',
#                                                    'type': 'GRID'}],
#                               'name': 'Albert-Ludwigs-Universität Freiburg'},
#               'firstname': 'S.',
#               'fullname': 'S. Zimmermann',
#               'lastname': 'Zimmermann',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2375 0603',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.435824.c',
#                                                    'type': 'GRID'}],
#                               'name': 'Max-Planck-Institut für Physik '
#                                       '(Werner-Heisenberg-Institut)'},
#               'firstname': 'Z.',
#               'fullname': 'Z. Zinonos',
#               'lastname': 'Zinonos',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 1941 7111',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.5802.f',
#                                                    'type': 'GRID'}],
#                               'name': 'Universität Mainz'},
#               'firstname': 'M.',
#               'fullname': 'M. Zinser',
#               'lastname': 'Zinser',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2242 8751',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.5836.8',
#                                                    'type': 'GRID'}],
#                               'name': 'Universität Siegen'},
#               'firstname': 'M.',
#               'fullname': 'M. Ziolkowski',
#               'lastname': 'Ziolkowski',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 0701 8607',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.28803.31',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Wisconsin'},
#               'firstname': 'G.',
#               'fullname': 'G. Zobernig',
#               'lastname': 'Zobernig',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1757 1758',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.6292.f',
#                                                    'type': 'GRID'}],
#                               'name': 'INFN Bologna and Universita’ di '
#                                       'Bologna'},
#               'firstname': 'A.',
#               'fullname': 'A. Zoccoli',
#               'lastname': 'Zoccoli',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2364 4210',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.7450.6',
#                                                    'type': 'GRID'}],
#                               'name': 'Georg-August-Universität Göttingen'},
#               'firstname': 'K.',
#               'fullname': 'K. Zoch',
#               'lastname': 'Zoch',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 9262',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.11835.3e',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Sheffield'},
#               'firstname': 'T. G.',
#               'fullname': 'T. G. Zorbas',
#               'lastname': 'Zorbas',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0004 1936 7822',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.170205.1',
#                                                    'type': 'GRID'}],
#                               'name': 'University of Chicago'},
#               'firstname': 'R.',
#               'fullname': 'R. Zou',
#               'lastname': 'Zou',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2248 7639',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.7468.d',
#                                                    'type': 'GRID'}],
#                               'name': 'Humboldt Universität zu Berlin'},
#               'firstname': 'M.',
#               'fullname': 'M. Zur Nedden',
#               'lastname': 'Zur Nedden',
#               'role': 'aut'},
#              {'affiliation': {'affiliation_ids': [{'id': '0000 0001 2156 142X',
#                                                    'type': 'ISNI'},
#                                                   {'id': 'grid.9132.9',
#                                                    'type': 'GRID'}],
#                               'name': 'CERN'},
#               'firstname': 'L.',
#               'fullname': 'L. Zwalinski',
#               'lastname': 'Zwalinski',
#               'role': 'aut'}],
#  'primary_id': {'id': 's10052-019-7027-6', 'type': 'SPRINGER'},
#  'subject_terms': [],
#  'title': 'Measurement of $$W^{\\pm }Z$$ production cross sections and gauge '
#           'boson polarisation in pp collisions at $$\\sqrt{s} = 13~\\text '
#           '{TeV}$$ with the ATLAS detector',
#  'urls': [{'access_info': 'OALizenz',
#            'scope': '34',
#            'url': 'https://dx.doi.org/10.1140/epjc/s10052-019-7027-6'}]}
# ### Measurement of $W^{\pm }Z$ production cross sections and gauge boson polarisation in pp collisions at $\sqrt{s} = 13~\text {TeV}$ with the ATLAS detector
#
# Zeitschrift: The European Physical Journal C (2019)
#
# Abstract
#
# This paper presents measurements of $W^{\pm }Z$ production cross sections in pp collisions at a centre-of-mass energy of 13 $\text {TeV}$. The data were collected in 2015 and 2016 by the ATLAS experiment at the Large Hadron Collider, and correspond to an integrated luminosity of $36.1~\hbox {fb}^{-1}$. The $W^{\pm }Z$ candidate events are reconstructed using leptonic decay modes of the gauge bosons into electrons and muons. The measured inclusive cross section in the detector fiducial region for a single leptonic decay mode is $\sigma _{W^\pm Z \rightarrow \ell ^{'} \nu \ell \ell }^{\text {fid.}} = 63.7 \, \pm ~1.0~\text {(stat.)} \, \pm ~2.3~\text {(syst.)} \, \pm ~1.4~\text {(lumi.)}$ fb, reproduced by the next-to-next-to-leading-order Standard Model prediction of $61.5^{+1.4}_{-1.3}$ fb. Cross sections for $W^+Z$ and $W^-Z$ production and their ratio are presented as well as differential cross sections for several kinematic observables. An analysis of angular distributions of leptons from decays of W and Z bosons is performed for the first time in pair-produced events in hadronic collisions, and integrated helicity fractions in the detector fiducial region are measured for the W and Z bosons separately. Of particular interest, the longitudinal helicity fraction of pair-produced vector bosons is also measured.
